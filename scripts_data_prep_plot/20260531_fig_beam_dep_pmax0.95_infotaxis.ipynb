# %% [markdown]
# # Fig: Infotaxis, beam-dependent PM/PFA: pmax_th=0.95
#
# Reference:
# - `20251230_fig_mismatch_agent_truth_efficiency_comparison.ipynb`

# %%
from pathlib import Path

import pandas as pd

import seaborn as sns

# %%
from plot_utils import bar_violinplot_success_beam_dep
from simulation_data_prep import get_success_fname

# %%
# Set path
path_data = Path("/Volumes/ssd_2tb_1/infotaxis_simu_2026")

path_fig = Path("../figs_paper_2026")

# %%
cr_all = [5, 10]
br_all = [1, 2]
pm_all = [0.001, 0.002, 0.005, 0.01]

beam_sigma_r = {
    1: 0.5,
    2: 1,
}
beam_scale_all = [3, 5]

for cr in cr_all:
    for br in br_all:
        for beam_scale in beam_scale_all:

            path_left = path_data / "20260530_infotaxis_match_summary_compiled_pmax095_pmaxDiff1e-5"
            path_right = path_data / "20260530_infotaxis_beam_dep_summary_compiled_pmax095_pmaxDiff1e-5"
            pmax_th = 0.95
            pmax_diff_th = 1e-5

            df_x_all = []
            df_y_all = []
            for pm in pm_all:
                # Load summary and ph details
                df_x = pd.read_csv(
                    path_left / get_success_fname(
                        search_type="infotaxis", cr=cr, br=br, simulation_type="simple",
                        pmax_th=pmax_th, pmax_diff_th=pmax_diff_th,
                        pm_agent=pm
                    ), index_col=0
                )
                df_y = pd.read_csv(
                    path_right / get_success_fname(
                        search_type="infotaxis", cr=cr, br=br, simulation_type="beam_dep",
                        pmax_th=pmax_th, pmax_diff_th=pmax_diff_th,
                        pm_agent=pm, pm_truth=pm,
                        beam_sigma_r=beam_sigma_r[br], beam_scale=beam_scale
                    ), index_col=0
                )
                df_x_all.append(df_x)
                df_y_all.append(df_y)


            fig = bar_violinplot_success_beam_dep(
                cr=cr, br=br, pm_all=pm_all,
                df_x_all=df_x_all, df_y_all=df_y_all,
                x_str="Constant", y_str="Beam-dependent",
                stats_type="less",
                title_str_additional=f"Beam scaling={beam_scale}",
                colors=sns.color_palette("Set2"),
                colors_dark=sns.color_palette("Dark2"),
                color_idx_left=0, color_idx_right=2,
                print_stats=True,
                crowded_bars=False
            )

            fig.savefig(
                path_fig / f"fig_beam_dep_cr{cr}_br{br}_scale{beam_scale}_pmaxTh0.95_pmaxDiff1e-5_infotaxis.png",
                dpi=300, bbox_inches="tight"
            )
# Out:
# Samples: left:  989    right:  981
# Mean:    left: 10.498  right: 11.093
# Median:  left: 10.000  right: 11.000
#
# MWU test
#  - different: 0.00240
#  - less:      0.00120
#  - greater:   0.99880
# --------------------------------------------
# Samples: left:  983    right:  985
# Mean:    left: 10.581  right: 12.009
# Median:  left: 10.000  right: 12.000
#
# MWU test
#  - different: 0.00000
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
# Samples: left:  972    right:  979
# Mean:    left: 11.529  right: 13.997
# Median:  left: 11.000  right: 13.000
#
# MWU test
#  - different: 0.00000
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
# Samples: left:  991    right:  968
# Mean:    left: 12.764  right: 17.444
# Median:  left: 12.000  right: 16.000
#
# MWU test
#  - different: 0.00000
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
# Samples: left:  989    right:  974
# Mean:    left: 10.498  right: 11.409
# Median:  left: 10.000  right: 11.000
#
# MWU test
#  - different: 0.00001
#  - less:      0.00001
#  - greater:   0.99999
# --------------------------------------------
# Samples: left:  983    right:  976
# Mean:    left: 10.581  right: 12.466
# Median:  left: 10.000  right: 12.000
#
# MWU test
#  - different: 0.00000
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
# Samples: left:  972    right:  973
# Mean:    left: 11.529  right: 15.801
# Median:  left: 11.000  right: 15.000
#
# MWU test
#  - different: 0.00000
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
# Samples: left:  991    right:  969
# Mean:    left: 12.764  right: 22.079
# Median:  left: 12.000  right: 20.000
#
# MWU test
#  - different: 0.00000
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
# Samples: left:  977    right:  987
# Mean:    left: 7.558  right: 8.532
# Median:  left: 7.000  right: 8.000
#
# MWU test
#  - different: 0.00000
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
# Samples: left:  984    right:  976
# Mean:    left: 8.227  right: 9.533
# Median:  left: 8.000  right: 9.000
#
# MWU test
#  - different: 0.00000
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
# Samples: left:  980    right:  965
# Mean:    left: 9.080  right: 12.654
# Median:  left: 9.000  right: 12.000
#
# MWU test
#  - different: 0.00000
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
# Samples: left:  974    right:  963
# Mean:    left: 11.134  right: 19.362
# Median:  left: 10.000  right: 18.000
#
# MWU test
#  - different: 0.00000
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
# Samples: left:  977    right:  975
# Mean:    left: 7.558  right: 9.120
# Median:  left: 7.000  right: 9.000
#
# MWU test
#  - different: 0.00000
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
# Samples: left:  984    right:  966
# Mean:    left: 8.227  right: 10.495
# Median:  left: 8.000  right: 10.000
#
# MWU test
#  - different: 0.00000
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
# Samples: left:  980    right:  949
# Mean:    left: 9.080  right: 15.484
# Median:  left: 9.000  right: 15.000
#
# MWU test
#  - different: 0.00000
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
# Samples: left:  974    right:  966
# Mean:    left: 11.134  right: 26.392
# Median:  left: 10.000  right: 24.000
#
# MWU test
#  - different: 0.00000
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
# Samples: left:  986    right:  981
# Mean:    left: 29.492  right: 30.129
# Median:  left: 28.000  right: 28.000
#
# MWU test
#  - different: 0.39251
#  - less:      0.19626
#  - greater:   0.80377
# --------------------------------------------
# Samples: left:  982    right:  983
# Mean:    left: 29.827  right: 31.894
# Median:  left: 28.000  right: 31.000
#
# MWU test
#  - different: 0.01436
#  - less:      0.00718
#  - greater:   0.99282
# --------------------------------------------
# Samples: left:  985    right:  978
# Mean:    left: 31.165  right: 35.720
# Median:  left: 30.000  right: 33.000
#
# MWU test
#  - different: 0.00001
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
# Samples: left:  985    right:  971
# Mean:    left: 33.924  right: 44.283
# Median:  left: 33.000  right: 39.000
#
# MWU test
#  - different: 0.00000
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
# Samples: left:  986    right:  987
# Mean:    left: 29.492  right: 30.736
# Median:  left: 28.000  right: 29.000
#
# MWU test
#  - different: 0.14850
#  - less:      0.07425
#  - greater:   0.92576
# --------------------------------------------
# Samples: left:  982    right:  984
# Mean:    left: 29.827  right: 32.226
# Median:  left: 28.000  right: 31.000
#
# MWU test
#  - different: 0.00851
#  - less:      0.00425
#  - greater:   0.99575
# --------------------------------------------
# Samples: left:  985    right:  976
# Mean:    left: 31.165  right: 39.677
# Median:  left: 30.000  right: 36.000
#
# MWU test
#  - different: 0.00000
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
# Samples: left:  985    right:  959
# Mean:    left: 33.924  right: 52.423
# Median:  left: 33.000  right: 47.000
#
# MWU test
#  - different: 0.00000
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
# Samples: left:  980    right:  981
# Mean:    left: 15.112  right: 16.614
# Median:  left: 14.000  right: 16.000
#
# MWU test
#  - different: 0.00000
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
# Samples: left:  981    right:  981
# Mean:    left: 16.005  right: 18.513
# Median:  left: 15.000  right: 17.000
#
# MWU test
#  - different: 0.00000
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
# Samples: left:  978    right:  971
# Mean:    left: 17.629  right: 24.678
# Median:  left: 17.000  right: 23.000
#
# MWU test
#  - different: 0.00000
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
# Samples: left:  966    right:  961
# Mean:    left: 21.005  right: 37.656
# Median:  left: 20.000  right: 36.000
#
# MWU test
#  - different: 0.00000
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
# Samples: left:  980    right:  978
# Mean:    left: 15.112  right: 17.046
# Median:  left: 14.000  right: 16.000
#
# MWU test
#  - different: 0.00000
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
# Samples: left:  981    right:  967
# Mean:    left: 16.005  right: 19.547
# Median:  left: 15.000  right: 18.000
#
# MWU test
#  - different: 0.00000
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
# Samples: left:  978    right:  957
# Mean:    left: 17.629  right: 29.958
# Median:  left: 17.000  right: 28.000
#
# MWU test
#  - different: 0.00000
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
# Samples: left:  966    right:  957
# Mean:    left: 21.005  right: 52.180
# Median:  left: 20.000  right: 50.000
#
# MWU test
#  - different: 0.00000
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
