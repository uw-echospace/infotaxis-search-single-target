# %% [markdown]
# # Fig: Distribution of last h_actual in mismatch agentHigher scenario: pmax_th=0.95
#
# Reference:
# - `20260531_fig_infotaxis_MAP_cmp_pmax0.95.ipynb`

# %%
from pathlib import Path

import pandas as pd

import seaborn as sns

# %%
from data_prep_plot.plot_utils import bar_violinplot_last_h_actual
from data_prep_plot.simulation_data_prep import get_success_fname

# %%
# Set path
path_data = Path("/Volumes/ssd_2tb_1/infotaxis_simu_2026")

path_fig = Path("../figs_paper_2026")

# %%
cr_all = [5, 10]
br_all = [1, 2]
pm_agent_all = [0.005, 0.01, 0.02, 0.05]
pm_truth_all = [0.001] * len(pm_agent_all)


for cr in cr_all:
    for br in br_all:

        path_left = path_data / "20260530_infotaxis_match_summary_compiled_pmax095_pmaxDiff1e-5"
        path_right = path_data / "20260530_infotaxis_mismatch_agentHigher_summary_compiled_pmax095_pmaxDiff1e-5"
        pmax_th = 0.95
        pmax_diff_th = 1e-5

        df_x_all = []
        df_y_all = []
        for pm_agent, pm_truth in zip(pm_agent_all, pm_truth_all):
            # Load summary and ph details
            df_x = pd.read_csv(
                path_left / get_success_fname(
                    search_type="infotaxis", cr=cr, br=br, simulation_type="simple",
                    pmax_th=pmax_th, pmax_diff_th=pmax_diff_th,
                    pm_agent=pm_truth
                ), index_col=0
            )
            df_y = pd.read_csv(
                path_right / get_success_fname(
                    search_type="infotaxis", cr=cr, br=br, simulation_type="mismatch",
                    pmax_th=pmax_th, pmax_diff_th=pmax_diff_th,
                    pm_agent=pm_agent, pm_truth=pm_truth
                ), index_col=0
            )
            df_x_all.append(df_x)
            df_y_all.append(df_y)

        
        fig = bar_violinplot_last_h_actual(
            cr=cr, br=br, pm_all=pm_agent_all,
            df_x_all=df_x_all, df_y_all=df_y_all,
            x_str="Matched", y_str="Mismatched (agent higher)",
            comparison_type="agent_higher",
            stats_type="two-sided",
            bar_step=0.05,
            crowded_bars=False,
            colors=sns.color_palette("Set2"),
            colors_dark=sns.color_palette("Dark2"),
            color_idx_left=0, color_idx_right=2,
            alpha=0.65
        )

        fig.savefig(
            path_fig / f"fig_last_h_actual_mismatch_agentHigher_cr{cr}_br{br}_pmaxTh0.95_pmaxDiff1e-5.png",
            dpi=300, bbox_inches="tight"
        )
# Out:
# Samples: left:  989    right:  996
# Mean:    left: 0.122  right: 0.171
# Median:  left: 0.120  right: 0.138
#
# MWU test
#  - different: 0.00000
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
# Samples: left:  989    right:  999
# Mean:    left: 0.122  right: 0.184
# Median:  left: 0.120  right: 0.146
#
# MWU test
#  - different: 0.00000
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
# Samples: left:  989    right: 1000
# Mean:    left: 0.122  right: 0.267
# Median:  left: 0.120  right: 0.254
#
# MWU test
#  - different: 0.00000
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
# Samples: left:  989    right: 1000
# Mean:    left: 0.122  right: 0.312
# Median:  left: 0.120  right: 0.306
#
# MWU test
#  - different: 0.00000
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
# Samples: left:  977    right:  997
# Mean:    left: 0.173  right: 0.212
# Median:  left: 0.163  right: 0.192
#
# MWU test
#  - different: 0.00000
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
# Samples: left:  977    right: 1000
# Mean:    left: 0.173  right: 0.278
# Median:  left: 0.163  right: 0.265
#
# MWU test
#  - different: 0.00000
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
# Samples: left:  977    right: 1000
# Mean:    left: 0.173  right: 0.318
# Median:  left: 0.163  right: 0.313
#
# MWU test
#  - different: 0.00000
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
# Samples: left:  977    right: 1000
# Mean:    left: 0.173  right: 0.361
# Median:  left: 0.163  right: 0.370
#
# MWU test
#  - different: 0.00000
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
# Samples: left:  986    right: 1000
# Mean:    left: 0.170  right: 0.154
# Median:  left: 0.148  right: 0.127
#
# MWU test
#  - different: 0.00002
#  - less:      0.99999
#  - greater:   0.00001
# --------------------------------------------
# Samples: left:  986    right: 1000
# Mean:    left: 0.170  right: 0.173
# Median:  left: 0.148  right: 0.129
#
# MWU test
#  - different: 0.45546
#  - less:      0.77230
#  - greater:   0.22773
# --------------------------------------------
# Samples: left:  986    right: 1000
# Mean:    left: 0.170  right: 0.267
# Median:  left: 0.148  right: 0.259
#
# MWU test
#  - different: 0.00000
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
# Samples: left:  986    right: 1000
# Mean:    left: 0.170  right: 0.336
# Median:  left: 0.148  right: 0.317
#
# MWU test
#  - different: 0.00000
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
# Samples: left:  980    right:  998
# Mean:    left: 0.179  right: 0.231
# Median:  left: 0.165  right: 0.208
#
# MWU test
#  - different: 0.00000
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
# Samples: left:  980    right:  998
# Mean:    left: 0.179  right: 0.289
# Median:  left: 0.165  right: 0.280
#
# MWU test
#  - different: 0.00000
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
# Samples: left:  980    right: 1000
# Mean:    left: 0.179  right: 0.345
# Median:  left: 0.165  right: 0.334
#
# MWU test
#  - different: 0.00000
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
# Samples: left:  980    right: 1000
# Mean:    left: 0.179  right: 0.403
# Median:  left: 0.165  right: 0.404
#
# MWU test
#  - different: 0.00000
#  - less:      0.00000
#  - greater:   1.00000
# --------------------------------------------
